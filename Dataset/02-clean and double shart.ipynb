# %%
import pandas as pd
import re

# Load data
df = pd.read_csv('FAZ_POEMS_REVIEW-DONT DELETE.csv')
print(f"Loaded {len(df)} rows")
print(f"Total poems: {df['poem_ID'].nunique()}")
# Out:
# Loaded 11349 rows
# Total poems: 353

# %%
# Remove rows with empty Poem_line_Raw
before = len(df)
df = df[df['Poem_line_Raw'].notna() & (df['Poem_line_Raw'].str.strip() != '')].copy()
df = df.reset_index(drop=True)
print(f"Removed {before - len(df)} empty rows")
print(f"Remaining: {len(df)} rows")
# Out:
# Removed 2921 empty rows
# Remaining: 8428 rows

# %%
# Find rows with English characters (excluding X/x)
def has_english_except_x(text):
    if pd.isna(text):
        return False
    # Remove X and x firsts
    text_no_x = re.sub(r'[Xx]', '', str(text))
    # Check for any remaining English letters
    return bool(re.search(r'[A-WYZa-wyz]', text_no_x))

english_mask = (df['Poem_line_Raw'].apply(has_english_except_x) | 
                df['Title_Raw'].apply(has_english_except_x))

english_rows = df[english_mask].copy()

if len(english_rows) > 0:
    print(f"⚠ Found {len(english_rows)} rows with English characters:\n")
    print(english_rows[['ROW_ID', 'poem_ID', 'Title_Raw', 'Poem_line_Raw']].to_string(index=False))
    print(f"\n⚠ Review above - manually delete unwanted rows from CSV if needed")
    print("✓ Continuing to next cell...")
else:
    print("✓ No English characters found - approved!")
# Out:
# ⚠ Found 3 rows with English characters:
#
#  ROW_ID  poem_ID   Title_Raw                                   Poem_line_Raw
#    9625      239 هدهد سليمان                  لـمـا تروبه Many feeling apear
#    9626      239 هدهد سليمان      The night and darkness have many relations
#    9627      239 هدهد سليمان والعالــــــــــــــــم نشوبه It goes and comes
#
# ⚠ Review above - manually delete unwanted rows from CSV if needed
# ✓ Continuing to next cell...

# %%
# Concatenate lines into bait (couplets) with \t separator
results = []

for poem_id in df['poem_ID'].unique():
    poem_lines = df[df['poem_ID'] == poem_id].sort_values('ROW_ID')
    title_raw = poem_lines.iloc[0]['Title_Raw']
    title_cleaned = poem_lines.iloc[0]['Title_cleaned']
    
    lines_raw = poem_lines['Poem_line_Raw'].tolist()
    lines_cleaned = poem_lines['Poem_line_cleaned'].tolist()
    
    # Pair lines into bait (2 lines per bait)
    for i in range(0, len(lines_raw), 2):
        if i + 1 < len(lines_raw):
            # Normal pair
            bait_raw = lines_raw[i] + "      " + lines_raw[i+1]
            bait_cleaned = lines_cleaned[i] + "      " + lines_cleaned[i+1]
        else:
            # Odd line (single)
            bait_raw = lines_raw[i]
            bait_cleaned = lines_cleaned[i]
        
        results.append({
            'poem_id': poem_id,
            'bait_index': i // 2 + 1,
            'title_raw': title_raw,
            'title_cleaned': title_cleaned,
            'bait_raw': bait_raw,
            'bait_cleaned': bait_cleaned
        })

bait_df = pd.DataFrame(results)

print(f"Created {len(bait_df)} bait from {len(df)} lines")
print(f"\nSample bait (first 5):\n")
for i in range(min(5, len(bait_df))):
    print(f"Poem {bait_df.iloc[i]['poem_id']} - Bait {bait_df.iloc[i]['bait_index']}:")
    print(f"  {bait_df.iloc[i]['bait_raw']}")
    print()

# Check for odd bait counts
odd_bait = bait_df[~bait_df['bait_raw'].str.contains('\t')]
if len(odd_bait) > 0:
    odd_poems = odd_bait.groupby('poem_id').size().reset_index(name='odd_bait_count')
    odd_poems = odd_poems.merge(
        bait_df.groupby('poem_id')['title_cleaned'].first().reset_index(),
        on='poem_id'
    )
    print(f"\n⚠ Found {len(odd_poems)} poems with odd lines:\n")
    print(odd_poems.to_string(index=False))
else:
    print("\n✓ All poems have even line counts - approved!")
# Out:
# Created 4215 bait from 8428 lines
#
# Sample bait (first 5):
#
# Poem 1 - Bait 1:
#   حبيـبتي حالـي من الشــوق دانــي      أشــرّق بحـبّــك .. واعـوّد أغـرّب
#
# Poem 1 - Bait 2:
#   أنـانـي فْـ وصـلك لـكـن يالأنـاني      تـرى الأنانـيّـه فْـ طـبـعـك تـخــرّب
#
# Poem 1 - Bait 3:
#   لحظات حبّـك حطّـمت لي كـياني      والحزن من بين الـمحـاني تـسـرّب
#
# Poem 1 - Bait 4:
#   تـسـرّب وصـكّـت عـلـيه الـمـحاني      كـنّـه لـوصـلك بالـجـروح يْـتـقـرّب
#
# Poem 1 - Bait 5:
#   يا مْعـرّب الأنـسـاب خـدر العـياني      سِـلْـم العـرب لا تجهـله يـالـمـعـرّب
#
#
# ⚠ Found 353 poems with odd lines:
#
#  poem_id  odd_bait_count                         title_cleaned
#        1               6                          لا تسال مجرب
#        2               9                             ثلاث مرات
#        3              20                  هواء الامارات وثراها
#        4              10                                  يتيم
#        5              11                          مرت علي بالي
#        6               8                           لا تلبس ذهب
#        7               8                          لا تسال مجرب
#        8              19                             قصر زعبيل
#        9               9                             قلب السبع
#       10              20                          شعب الامارات
#       11              10                             سهم الغلا
#       12               7                                  سامح
#       13              20                        رمز العز علمني
#       14              18                           ديوان العرب
#       15              19                           جسر الصداقه
#       16              24                             تجربه عمر
#       17              16                               اول عشق
#       18               9                                 الهجر
#       19              25                               اسف اسف
#       20              19                            احمر الورد
#       21              11                              انت وانا
#       22              10                            الغصن يابس
#       23             103                          ايمان الشعوب
#       24              24                        قصيده المستحيل
#       25               8                               مرت سنه
#       26              12                                 الاسم
#       27               7                                   ادب
#       28              11                          اذا قالت الو
#       29              15                          واحد x اثنين
#       30              14                           ابليس ملعون
#       31               8                             ارسم غرام
#       32              12                           اريد اتفلسف
#       33              10                             ازعل عليك
#       34              12                               استجواب
#       35               5                       اسف علي التاخير
#       36              24                       اشياء .. واشياء
#       37              31                                 اعمار
#       38              11                         افا والله افا
#       39               4                             اقرب تعال
#       40               8                               الف عام
#       41              10                           الي البراءه
#       42              16                          امجاد الجدود
#       43              12                           امتحانك صعب
#       44              10                        امر يا بو خالد
#       45               8                             امشي بعزم
#       46               8                          انا في الشعر
#       47               8                            انا و عيني
#       48               9                                انتباه
#       49               8                          انصاف الحلول
#       50               8                                اوراقي
#       51              10                                 اوربت
#       52              12                       الاخير .. الاول
#       53              12                                 البدر
#       54               9                                الجروح
#       55              21                       الزعل ماهو دموع
#       56              11                               السالفه
#       57               6                                 السمو
#       58              25                        السمو والمعالي
#       59              16                           الشاعر اللي
#       60               9                         الصاحب المعني
#       61              15                       الغول و العنقاء
#       62              10                        الفصول الاربعه
#       63               8                          القضا بالقضا
#       64              20                           المورد واحد
#       65              10                                الموعد
#       66              26                        الناس بالاحساس
#       67               9                        اول انسان احبه
#       68              14                              بالمختصر
#       69               9                                  بحور
#       70               8                             برج العرب
#       71               9                              برج عاجي
#       72              10                                 بعلبك
#       73              13                        بن و هيل و تمر
#       74              16                            بنات الريح
#       75              18                          بياض التجربه
#       76               8                            بيت في حرف
#       77              11                                ترنيمه
#       78              12                          تعال واسالني
#       79              11                         تناهيت المحبه
#       80               8                           تهاني العيد
#       81               8                                  توبه
#       82              20                              ثقه زايد
#       83               9                             ثلاث ايام
#       84               8                            ثمار الهوي
#       85              11                           جرح الصداقه
#       86              22                   جودنا ينجاد منه جود
#       87              40                            حارث البحر
#       88              11                             حبال صوتك
#       89              10                            حديقه ورود
#       90              11                             حراس قلبي
#       91               8                                   حصه
#       92              17                            حكومه الحب
#       93              16                              حلوه موت
#       94              10                          حمام الاحباب
#       95               9                                 حمايم
#       96              13                    خذ من الشاعر كلامه
#       97               8                             خلاص يعني
#       98              20                                 دراهم
#       99              10                          دروب الارانب
#      100               8                           دلال و مسند
#      101              13                          دموع المحبين
#      102              16                            خير الكلام
#      103              14                           ديره الغربه
#      104              14                              ديمقراطي
#      105              64                               ذيب عوي
#      106              38                             رجل مثالي
#      107              10                         رساله الي امي
#      108               8                                  زايد
#      109              14                              سريه فكر
#      110              11                             سكر زياده
#      111              21                            سلام تسليم
#      112              26                            سمح الجناب
#      113               9                                  سءال
#      114              10                                  سيدي
#      115              17                          شاعر ارتجالي
#      116              11                            شاعر مشاعر
#      117               7                        سيدي لا عدمناك
#      118               5                             شرق و غرب
#      119               9                             شي ولا شي
#      120               6                             شفه الصمت
#      121               8                            شيخه الغيد
#      122              11                               شياطينك
#      123               8                             صبري ملني
#      124               6                             صد و بعاد
#      125              10                                 صراحه
#      126              26                             ضرس و ناب
#      127              10                            طاحت الحيه
#      128              14                              طويه زمن
#      129               8                             طيب القلب
#      130              20                            عاتق المجد
#      131               9                             عالم ثاني
#      132               8                               عذروبها
#      133               8                             علي الخطا
#      134              26                              علي رفقه
#      135               8                          عوضوك بغيابي
#      136               9                             عين الرضا
#      137               9                              غصون قاف
#      138              14                                   غلا
#      139              13                                  غياب
#      140               7                                  فارس
#      141              34                           فخر الاجيال
#      142              12                             فرض و نفل
#      143              16                              فز الشبل
#      144              10                             فصول عمري
#      145              11                             فمان الله
#      146              14                            فنون الغدر
#      147              12                         فهمت وما فهمت
#      148              10                         في خاطرك حاجه
#      149               8                             قال المثل
#      150               8                           قدها و قدود
#      151              20                             قراءه مدي
#      152              10                           قصيده ساجده
#      153               8                              قلب صادق
#      154               8                            قلبي وعيني
#      155              13                           قلوبنا قبرك
#      156              24                            قنبله ذريه
#      157              14                           قوس الربابه
#      158              12                               قوس قزح
#      159              10                            كحل الظلام
#      160              14                                كحيلان
#      161              12                                كش ملك
#      162               8                             كلمه سلام
#      163               6                       لا جمع و لا طرح
#      164              10                             لا تدورها
#      165              10                      لا تسمع ولا توحي
#      166              14                         لا تغرك ضحكتي
#      167               9                         لا تلعن الفقر
#      168               8                              لا تندفع
#      169              10                                  لبيه
#      170              10                           لحن المفارق
#      171              24                              لعبه زمن
#      172              11                               لله درك
#      173              13                                لم تري
#      174              14                          ليل وراه ليل
#      175              28          ليه .. و كيف .. و عن .. و من
#      176               9                        ما كان له داعي
#      177              12                          ما يشل الراس
#      178              14                            مدخل غرامي
#      179               7                                 مراجل
#      180              10                            مرثيه زايد
#      181              14                                  مريم
#      182               8                          مستحيل انساك
#      183              82                         معلقه الاتحاد
#      184               9                                  مطار
#      185              15                            مطر .. مطر
#      186               9                              ملاذ عمر
#      187              11                     من الف ليله وليله
#      188              10                من حاء ميم الي نون الف
#      189              18                     من عرفته ما ذرفته
#      190              10                            من هو فزاع
#      191               9                               من يحبك
#      192               9                             ميلاد مجد
#      193               8                            نبع المحبه
#      194              23                            نخوه قوافي
#      195               8                           ندي الريحان
#      196              14                هذا الشبل من ذاك الاسد
#      197              11                             هذي طبوعي
#      198              12                                هنيالي
#      199               9                            هوا الحريه
#      200               7                                  وسمي
#      201               6                             وضوح الما
#      202              30  ولا يقدر يلم الشمل غير القايد الربان
#      203              11                             وين انت ؟
#      204               9                               يا ايها
#      205               9                               يا احمد
#      206              10                              يابن ادم
#      207              20                            يا حبني له
#      208               8                          يا سلام الله
#      209              18                          يا عيب الشوم
#      210               8                         يا مشعل القلب
#      211              10                             يحسب حساب
#      212              10                   يراودك .. و يراودني
#      213               9                            يوم الوداع
#      214              10                          اجلس مع نفسك
#      215               9             سيداتي .. انساتي .. سادتي
#      216               6                     الوطن كله... ابوك
#      217              10                         مراحل العمر..
#      218               8                             حب المطيه
#      219              20                            ثلاثيه نصر
#      220              27               سلام من فزاع لاهل الهجن
#      221              10                         يا موحد الدار
#      222               6                                   ذوق
#      223               5                               اليمامه
#      224              10                            موطن الفخر
#      225              18                         في السما دروب
#      226               9                           فلم الطهاره
#      227              13               كبريت واحد .. والف غابه
#      228              48                        الجار للجار ..
#      229               9                           واجب الصحبه
#      230              20                          مهبط الاحلام
#      231              20                     وجه الحياه الثاني
#      232              10                       انا والبواخر ..
#      233              22                            قبر الشهيد
#      234              20                              كلمه اخي
#      235               8                               فكر شوي
#      236              23                           حكمه الشامخ
#      237              16                          ملهم القصيده
#      238               8                         فيها من الخيل
#      239              61                           هدهد سليمان
#      240               8                           ام الامارات
#      241              11                                 افترت
#      242               8                                القادر
#      243              20                            افهم مكانك
#      244              20                           اعذروا رماح
#      245              50                         ميدان التفاخر
#      246               7                         الزعيم الملهم
#      247               6 رد حمدان بن محمد علي ابيات:ضاحي خلفان
#      248              10                            الحزن راحه
#      249              13                            صاحب الهجر
#      250               4                         ميلاد ابوخالد
#      251              50                                 مفهوم
#      252              22                              عام زايد
#      253               8                           الطرشه خليه
#      254               8                             تامر عليه
#      255              12                            زبون الصبر
#      256              10                             سمي العود
#      257              15                             مده وافيه
#      258              19                             وقفه عرفه
#      259               5                             الكبر لله
#      260               7                         الورده ارتاحت
#      261              11                          قمه الالتحام
#      262              10                                  هداد
#      263               3                                شنذاره
#      264              16                            قنيب الذيب
#      265               4                                   ظما
#      266               8                            هامه المجد
#      267              10                         ثلاثميه قصيده
#      268               6                            وقفه عرفات
#      269               9                                  هديل
#      270              23                            بينك وبينه
#      271               4                              راحت سنه
#      272              40                   خمسين عام قبل و بعد
#      273               7                          في كل عام !!
#      274               6                           شعار الدوله
#      275               9                           حكمه الحطاب
#      276               6                            محيط افكار
#      277              19                           حلال الصعاب
#      278               9                                   وسم
#      279               4                                هدهدها
#      280               7                                 الظبي
#      281              13                       الشميمي و الخوي
#      282               6                                   هند
#      283               7                                مزهريه
#      284               2                                   رمز
#      285               4                                الجمعه
#      286               4                              ابو خالد
#      287              14                            الميت الحي
#      288              24                   عجايب وشنذاره وغياث
#      289               4                             ضحي العيد
#      290               2                                  دعاء
#      291              10                             درب الشعر
#      292               5                        عن هنا من هناك
#      293               2                                الصوره
#      294               2                               المدينه
#      295               2                         زايد بن حمدان
#      296               3                              صوره مجد
#      297               7                           ما عنه صدود
#      298               5                           فزاع و سفاح
#      299              14                             اراده وطن
#      300              13                             رساله حزن
#      301               2                                 علياء
#      302               4                                 خلابه
#      303               3                                 الديم
#      304               7                              رابع يوم
#      305               2                                الشجره
#      306               3                             كويت العز
#      307               8                            بيني وبينك
#      308               3                                من امس
#      309               5                            ترحيبه غيم
#      310               2                              ما انبله
#      311               6                               شهر سته
#      312               2                            ثلاث اعياد
#      313               5                               هذا دلع
#      314              10                         لو يضيق الصدر
#      315               8                        اغلي وصل وفراق
#      316               2                                 الشمس
#      317              10                            اقول لك تم
#      318               7                   شيخه وراشد في ظلالك
#      319               2                              نبره حزن
#      320               5                             وجه المجد
#      321               3                             ذكري حديث
#      322               2                            جبال الارض
#      323              13                            دمع العظيم
#      324               2                           الفخر والعز
#      325               4                         وسام ام الشعب
#      326               7                                 ابشرك
#      327               2                          احتضنك المجد
#      328               3                           سلطه و دفتر
#      329               2                            رقه طفولتك
#      330               2                            هذا الصغير
#      331               3                         الرويس وغياثي
#      332               6                        يعلمني الرمايه
#      333               7                   المشكله بين الاثنين
#      334               2                              في ثانيه
#      335               4              مجاراه لقصيده ضاحي خلفان
#      336               3                           اهل الرياده
#      337               2                                  حاجه
#      338               2                                 ادراك
#      339               6                            فكره شامله
#      340              11                       ذكرياتي مع راشد
#      341               3                             سيد المجد
#      342              12                             سءالك غلط
#      343               2                          حاضر ومستقبل
#      344               2                               الغزاله
#      345               2                                 قوارب
#      346               8                              الله لنا
#      347               2                           محمد الدوله
#      348               2                          نعمه من الله
#      349               3                            زايد وجابر
#      350               3                                   وفا
#      351               3                                   ابو
#      352              11                   اميره قلوب الانقياء
#      353               2                              ابن فراج

# %%
# Save final bait dataset
bait_df.to_csv('poems_bait_final.csv', index=False, encoding='utf-8-sig')
print(f"✓ Saved {len(bait_df)} bait to poems_bait_final.csv")
# Out:
# ✓ Saved 4215 bait to poems_bait_final.csv

# %% [markdown]
# # Full Poem GROUP

# %%
# Load your CSV (replace 'your_file.csv' with actual path)
df = pd.read_csv('FAZ_POEMS_REVIEW.csv', sep=',')

# Group by poem_id and aggregate
grouped = df.groupby('poem_id').agg({
    'Row_ID': 'first',  # or min, doesn't matter if you just need one
    'Title_raw': 'first',
    'Poem_line_raw': '\n'.join,
    'Title_cleaned': 'first',
    'Poem_line_cleaned': '\n'.join
}).reset_index()

# Reorder columns to match original order
grouped = grouped[['poem_id', 'Row_ID', 'Title_raw', 'Poem_line_raw', 'Title_cleaned', 'Poem_line_cleaned']]

# Save to new CSV (optional)
grouped.to_csv('poems_grouped.csv', index=False)

# Display result
print(grouped)
# Out:
#      poem_id  Row_ID             Title_raw  \
# 0          1       1       لا تسـأل مجـرّب
# 1          2       1         ثــلاث مـرّات
# 2          3       1  هواء الإمارات وثراها
# 3          4       1                  يتيم
# 4          5       1         مرت على بـالي
# ..       ...     ...                   ...
# 348      349       1            زايد وجابر
# 349      350       1                   وفا
# 350      351       1                  أبـو
# 351      352       1   أميرة قلوب الأنقياء
# 352      353       1             إبن فرّاج
#
#                                          Poem_line_raw         Title_cleaned  \
# 0    حبيـبتي حالـي من الشــوق دانــي      أشــرّق ب...          لا تسال مجرب
# 1    ثـــلاث مـرّات .. وانـت تـدوّر فـراقي      وثـ...             ثلاث مرات
# 2    صاحبي يافاهمٍ قصدي ترى ما كل ديره      آتـمـشّ...  هواء الامارات وثراها
# 3    يتيـم فـاقد شـوفة امّـه من سـنين      وابوه مـ...                  يتيم
# 4    حبـيـبتي مـرّت على بـالـي الـيـوم      وْ وقّـ...          مرت علي بالي
# ..                                                 ...                   ...
# 348  حمــدان ، راعي دار ليس بعـابـر      سبيل ، وال...            زايد وجابر
# 349  يا هلا من ضمير و مرحـبا كل سـاع      إحترامي ي...                   وفا
# 350  أنـتي وأنـا .. بكـره إلى من كبـــرنا      بانق...                   ابو
# 351  يا اميـرة قلوب الأتـقيا مـرّني طاريك      مرور...   اميره قلوب الانقياء
# 352  على كثر هالنـاس و الله ما فيهـم      مثلك يا ب...              ابن فراج
#
#                                      Poem_line_cleaned
# 0    حبيبتي حالي من الشوق داني      اشرق بحبك .. وا...
# 1    ثلاث مرات .. وانت تدور فراقي      وثلاث مرات ....
# 2    صاحبي يافاهم قصدي تري ما كل ديره      اتمشي في...
# 3    يتيم فاقد شوفه امه من سنين      وابوه مات من ا...
# 4    حبيبتي مرت علي بالي اليوم      و وقفت تقدير له...
# ..                                                 ...
# 348  حمدان ، راعي دار ليس بعابر      سبيل ، والعهد ...
# 349  يا هلا من ضمير و مرحبا كل ساع      احترامي يلي...
# 350  انتي وانا .. بكره الي من كبرنا      بانقول للا...
# 351  يا اميره قلوب الاتقيا مرني طاريك      مرور الس...
# 352  علي كثر هالناس و الله ما فيهم      مثلك يا بن ...
#
# [353 rows x 6 columns]
