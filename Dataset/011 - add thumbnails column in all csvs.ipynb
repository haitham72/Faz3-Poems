# %%
import pandas as pd

df = pd.read_csv("./CSV/Diwan-Hamdan-WIP - Word_search.csv")
df["ai_images_thumb"] = "/images/poems/" + df["poem_id"].astype(str) + "_Drive_New_Thumbnail_view.jpg"
df.to_csv("./CSV/Diwan-Hamdan-WIP - Word_search.csv", index=False)

# %%
df = pd.read_csv("./CSV/Diwan-Hamdan-WIP - Full_poems.csv")
df["ai_images_thumb"] = "/images/poems/" + df["poem_id"].astype(str) + "_Drive_New_Thumbnail_view.jpg"
df.to_csv("./CSV/Diwan-Hamdan-WIP - Full_poems.csv", index=False)

# %%
df = pd.read_csv("./CSV/Diwan-Hamdan-WIP - Semantic_search.csv")
df["ai_images_thumb"] = "/images/poems/" + df["poem_id"].astype(str) + "_Drive_New_Thumbnail_view.jpg"
df.to_csv("./CSV/Diwan-Hamdan-WIP - Semantic_search.csv", index=False)
