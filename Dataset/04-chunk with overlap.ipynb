# %%
import pandas as pd

def chunk_poems_with_overlap(input_csv, output_csv):
    """
    Chunk poems with:
    - 4 lines per chunk
    - 1-line overlap between chunks (step=3)
    - Final chunk always contains last 4 lines
    - Strict poem boundaries (no cross-poem chunks)
    - Preserves all original columns
    - Handles short poems appropriately
    """
    # Read input CSV
    df = pd.read_csv(input_csv)
    
    # Sort by poem_id and Row_ID to ensure correct ordering
    df = df.sort_values(['poem_id', 'Row_ID']).reset_index(drop=True)
    
    output_rows = []
    chunk_id_counter = 1
    
    # Process each poem separately
    for poem_id, group in df.groupby('poem_id'):
        lines = group['Poem_line_cleaned'].tolist()
        raw_lines = group['Poem_line_raw'].tolist()
        row_ids = group['Row_ID'].tolist()
        title_raw = group['Title_raw'].iloc[0]  # Same for entire poem
        title_cleaned = group['Title_cleaned'].iloc[0]  # Same for entire poem
        other_cols = {col: group[col].iloc[0] for col in df.columns 
                     if col not in ['Row_ID', 'Poem_line_raw', 'Poem_line_cleaned']}
        
        n_lines = len(lines)
        
        # Case 1: Poem has fewer than 4 lines - create single chunk
        if n_lines < 4:
            chunk_text = '\n'.join(lines)
            chunk_raw_text = '\n'.join(raw_lines)
            row_id_str = ','.join(map(str, row_ids))
            output_rows.append({
                'poem_id': poem_id,
                'chunk_id': chunk_id_counter,
                'Title_raw': title_raw,
                'Title_cleaned': title_cleaned,
                'Poem_line_raw': chunk_raw_text,
                'Poem_line_cleaned': chunk_text,
                'Row_IDs_in_chunk': row_id_str,
                'chunk_type': 'short_poem',
                **other_cols  # Include all other original columns
            })
            chunk_id_counter += 1
            continue
        
        # Case 2: Poem has 4+ lines
        regular_starts = []
        current_start = 0
        
        # Generate regular chunks with step=3 (1-line overlap)
        while current_start <= n_lines - 4:
            regular_starts.append(current_start)
            current_start += 3
        
        # Determine final chunk start position (must end at last line)
        final_start = n_lines - 4  # Always starts at last_line-3
        
        # Combine regular starts with final chunk start if needed
        all_starts = sorted(set(regular_starts + [final_start]))
        
        # Create chunks
        for start_idx in all_starts:
            end_idx = start_idx + 4
            # Safety check - should always have 4 lines here
            if end_idx > n_lines:
                continue
                
            chunk_lines = lines[start_idx:end_idx]
            chunk_raw_lines = raw_lines[start_idx:end_idx]
            chunk_row_ids = row_ids[start_idx:end_idx]
            
            chunk_text = '\n'.join(chunk_lines)
            chunk_raw_text = '\n'.join(chunk_raw_lines)
            row_id_str = ','.join(map(str, chunk_row_ids))
            chunk_type = 'final' if start_idx == final_start and start_idx not in regular_starts else 'regular'
            
            output_rows.append({
                'poem_id': poem_id,
                'chunk_id': chunk_id_counter,
                'Title_raw': title_raw,
                'Title_cleaned': title_cleaned,
                'Poem_line_raw': chunk_raw_text,
                'Poem_line_cleaned': chunk_text,
                'Row_IDs_in_chunk': row_id_str,
                'chunk_type': chunk_type,
                **other_cols  # Include all other original columns
            })
            chunk_id_counter += 1
    
    # Create output DataFrame
    output_df = pd.DataFrame(output_rows)
    
    # Save to CSV with UTF-8 encoding for Arabic text
    output_df.to_csv(output_csv, index=False, encoding='utf-8-sig')
    print(f"Successfully created {len(output_df)} chunks")
    print(f"Output saved to: {output_csv}")
    return output_df

# Direct execution
input_file = "FAZ_POEMS_REVIEW - FAZ_POEMS_Lines_Cleaned.csv"
output_file = "poems_chunked.csv"

result = chunk_poems_with_overlap(input_file, output_file)
# Out:
# Successfully created 1418 chunks
# Output saved to: poems_chunked.csv

# %%
# New Sentiment columns

import pandas as pd

df = pd.read_csv(".\CSV\Diwan-Hamdan-WIP - Semantic_search.csv")

def extract_summary(text):
    if pd.isna(text):
        return ""
    return text.split('---')[0]

df['Summary'] = df['Summary_chunked'].apply(extract_summary)
df.to_csv(".\CSV\Diwan-Hamdan-WIP - Semantic_search.csv", index=False)
df.head()
# Out:
#    poem_id  chunk_id     Title_raw  \
# 0        1         1  لا تسال مجرب
# 1        1         2  لا تسال مجرب
# 2        2         3     ثلاث مرات
# 3        2         4     ثلاث مرات
# 4        2         5     ثلاث مرات
#
#                                        Poem_line_raw  \
# 0  حبيـبتي حالـي من الشــوق دانــي      أشــرّق ب...
# 1  لحظات حبّـك حطّـمت لي كـياني      والحزن من بي...
# 2  ثـــلاث مـرّات .. وانـت تـدوّر فـراقي      وثـ...
# 3  عليك صــابر ، وهذي قيـمـة اخــلاقي      لأن أر...
# 4  بالرقّـه .. انت الأرَق ، وذوقك الراقي      وبي...
#
#                                      Summary_chunked  \
# 0  الشاعر يصف شوقه العميق لمحبوبته، متأرجحًا بين ...
# 1  لحظات الحب دمرت كيانه، وأدت إلى تسرب الحزن الع...
# 2  يعاتب الشاعر محبوبته التي تسعى للفراق بينما هو...
# 3  يصبر الشاعر على محبوبته، معتبرًا الصبر قيمة أخ...
# 4  يمدح الشاعر محبوبته لكونها الأرق والأكثر رقة و...
#
#                                              Summary Title_cleaned  \
# ...

# %%
# updated from word_search to new Symantic_search
import pandas as pd
import json
from collections import defaultdict

def parse_json(val):
    if pd.isna(val):
        return []
    try:
        return json.loads(str(val).replace("'", '"'))
    except:
        return []

def merge_list(group, col):
    items = set()
    for val in group[col].dropna():
        val_str = str(val).strip()
        if not val_str:
            continue
        # Case 1: looks like JSON list
        if val_str.startswith('[') and val_str.endswith(']'):
            try:
                parsed = json.loads(val_str.replace("'", '"'))
                if isinstance(parsed, list):
                    items.update(str(i).strip() for i in parsed if i)
                    continue
            except:
                pass
        # Case 2: plain comma-separated or single value
        if ',' in val_str:
            for part in val_str.split(','):
                cleaned = part.strip().strip('"[]')
                if cleaned:
                    items.add(cleaned)
        else:
            # single value
            items.add(val_str)
    return sorted(list(items))

def merge_entities(group):
    entity_map = defaultdict(lambda: {'resolved': set(), 'relation': None})
    for val in group['entities'].dropna():
        ents = parse_json(val)
        for ent in ents:
            name = ent.get('name')
            if not name:
                continue
            relation = ent.get('relation', '')
            resolved = set(ent.get('resolved_from', []))
            key = (name, relation)
            data = entity_map[key]
            data['resolved'].update(resolved)
            if relation:
                data['relation'] = relation
    merged = [
        {"name": name, "relation": rel if rel else None, "resolved_from": sorted(list(resolved))}
        for (name, rel), data in entity_map.items() if data['resolved']
    ]
    return merged

def merge_places(group):
    place_map = defaultdict(set)
    for val in group['places'].dropna():
        items = parse_json(val)
        for item in items:
            typ = item.get('type', 'unknown')
            name = item.get('name')
            if isinstance(name, list):
                place_map[typ].update([str(n).strip() for n in name])
            elif name:
                place_map[typ].add(str(name).strip())
    merged = []
    for typ, names in place_map.items():
        name_list = sorted(list(names))
        entry = {"name": name_list if len(name_list) > 1 else name_list[0], "type": typ}
        merged.append(entry)
    return merged

def merge_animals(group):
    animal_map = defaultdict(lambda: {'resolved': set(), 'type': None})
    for val in group['animals'].dropna():
        items = parse_json(val)
        for item in items:
            name = item.get('name')
            if not name:
                continue
            typ = item.get('type')
            resolved = set(item.get('resolved_from', []))
            key = name
            data = animal_map[key]
            data['resolved'].update([str(r).strip() for r in resolved])
            if typ:
                data['type'] = typ
    merged = [
        {"name": name, "type": data['type'], "resolved_from": sorted(list(data['resolved']))}
        for name, data in animal_map.items() if data['resolved'] or data['type']
    ]
    return merged

def add_merged_annotations(line_csv, chunk_csv, output_csv):
    line_df = pd.read_csv(line_csv, encoding='utf-8-sig')
    
    merged_data = {}
    for poem_id, group in line_df.groupby('poem_id'):
        merged_data[poem_id] = {
            'entities': merge_entities(group),
            'sentiments': merge_list(group, 'sentiments'),
            'events': merge_list(group, 'events'),
            'religion': merge_list(group, 'religion'),
            'subjects': merge_list(group, 'subjects'),
            'places': merge_places(group),
            'animals': merge_animals(group),
        }
    
    chunk_df = pd.read_csv(chunk_csv, encoding='utf-8-sig')
    
    def get_json(col, pid):
        data = merged_data.get(pid, {}).get(col, [])
        return json.dumps(data, ensure_ascii=False, separators=(',', ':'))
    
    for col in ['entities', 'sentiments', 'events', 'religion', 'subjects', 'places', 'animals']:
        chunk_df[col] = chunk_df['poem_id'].apply(lambda pid: get_json(col, pid))
    
    chunk_df.to_csv(output_csv, index=False, encoding='utf-8-sig')
    print(f"Added merged columns to {output_csv}")

# Usage

# Usage (replace with your actual file paths)
add_merged_annotations(".\CSV\Diwan-Hamdan-WIP - Word_search.csv", ".\CSV\Diwan-Hamdan-WIP - Semantic_search_updated.csv", "chunked_with_annotations.csv")
# Out:
# Added merged columns to chunked_with_annotations.csv
